# %%
import pandas as pd
data = r"C:\Users\MSI\ML-final-project\Academic-Predictor-machine-based-on-performance-\data\raw_data\cambodian_student_Study_habit_and_thier_performance - Academic_Predictor_Extended.csv"
df = pd.read_csv(data)
df.head()
# Out:
#    Gender  Age                       Hometown  \
# 0    Male   19             Phnom Penh (Urban)
# 1  Female   22  Province (Rural / Semi-Urban)
# 2    Male   18             Phnom Penh (Urban)
# 3    Male   19             Phnom Penh (Urban)
# 4    Male   20             Phnom Penh (Urban)
#
#                                 University    Year STEM_Major Diet_Quality  \
# 0  American University Of Phnom Penh(AUPP)  Year 2        Yes         good
# 1  American University Of Phnom Penh(AUPP)  Year 1        Yes    excellent
# 2  American University Of Phnom Penh(AUPP)  Year 1        Yes      Average
# 3  American University Of Phnom Penh(AUPP)  Year 2        Yes         good
# 4  American University Of Phnom Penh(AUPP)  Year 2        Yes      Average
#
#   Internet_Quality                      Employment      Study_Habit  ...  \
# 0             good  Unemployed / Full-time student         Cramming  ...
# 1             good  Unemployed / Full-time student    Regular study  ...
# ...

# %%
df.shape
# Out:
# (598, 24)

# %%
df.columns.tolist()
# Out:
# ['Gender',
#  'Age',
#  'Hometown',
#  'University',
#  'Year',
#  'STEM_Major',
#  'Diet_Quality',
#  'Internet_Quality',
#  'Employment',
#  'Study_Habit',
#  'Stress_Level',
#  'Self_Study_Hrs',
#  'Tutoring_Hrs_Wk',
#  'AI_Tool_Usage',
#  'Social_Media_Hrs',
#  'Gaming_Hrs',
#  'Exercise_Days_Wk',
#  'Sleep_Hrs',
#  'Attendance_Rate',
#  'Commute_Time',
#  'Study_Group_Freq',
#  'Extracurricular',
#  'GPA',
#  'Performance_Tier']

# %%
df.dtypes
# Out:
# Gender               object
# Age                   int64
# Hometown             object
# University           object
# Year                 object
# STEM_Major           object
# Diet_Quality         object
# Internet_Quality     object
# Employment           object
# Study_Habit          object
# Stress_Level         object
# Self_Study_Hrs       object
# Tutoring_Hrs_Wk      object
# AI_Tool_Usage        object
# Social_Media_Hrs     object
# Gaming_Hrs           object
# Exercise_Days_Wk     object
# Sleep_Hrs            object
# Attendance_Rate      object
# Commute_Time         object
# Study_Group_Freq     object
# Extracurricular      object
# GPA                 float64
# Performance_Tier     object
# dtype: object

# %%
print("Diet_Quality:     ", sorted(df["Diet_Quality"].unique()))
print(len(df["Diet_Quality"].unique()))
print("Internet_Quality: ", sorted(df["Internet_Quality"].unique()))
print(len(df["Internet_Quality"].unique()))
print("University:       ", sorted(df["University"].unique()))
print(len(df["University"].unique()))
print("Commute_Time:     ", sorted(df["Commute_Time"].unique()))
print(len(df["Commute_Time"].unique()))
print("Study_Group_Freq: ", sorted(df["Study_Group_Freq"].unique()))
print(len(df["Study_Group_Freq"].unique()))
# Out:
# Diet_Quality:      ['Average', 'Poor', 'excellent', 'good']
# 4
# Internet_Quality:  ['Excellent', 'Fair', 'Poor', 'good']
# 4
# University:        ['American University Of Phnom Penh(AUPP)', 'CamEd Business School', 'Cambodia Academy Of Digital Technology(CADT)', 'De Montfort University Cambodia', 'Institute of Technology of Cambodia(ITC)', 'Paragon University', 'Royal University Of Agriculture', 'Royal University Of Law and Economics', 'Royal University Of Law and Economics (RULE)', 'Royal University Of Phnom Penh(RUPP)', 'UTE', 'University Of Health Science (UHS)', 'University of Economics and Finance (UEF)', 'University of Puthisastra', 'University of puthisastra']
# 15
# Commute_Time:      ['15–30 minutes', '31–60 minutes', 'More than 1 hour', 'Under 15 minutes']
# 4
# Study_Group_Freq:  ['Frequently (Multiple times a week)', 'Never', 'Rarely (Before exams only)', 'Sometimes (Weekly)']
# 4

# %%
df.isnull().sum()
# Out:
# Gender              0
# Age                 0
# Hometown            0
# University          0
# Year                0
# STEM_Major          0
# Diet_Quality        0
# Internet_Quality    0
# Employment          0
# Study_Habit         0
# Stress_Level        0
# Self_Study_Hrs      0
# Tutoring_Hrs_Wk     0
# AI_Tool_Usage       0
# Social_Media_Hrs    0
# Gaming_Hrs          0
# Exercise_Days_Wk    0
# Sleep_Hrs           0
# Attendance_Rate     0
# Commute_Time        0
# Study_Group_Freq    0
# Extracurricular     0
# GPA                 5
# Performance_Tier    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Gender: 2 unique values
# Hometown: 2 unique values
# University: 15 unique values
# Year: 5 unique values
# STEM_Major: 2 unique values
# Diet_Quality: 4 unique values
# Internet_Quality: 4 unique values
# Employment: 3 unique values
# Study_Habit: 3 unique values
# Stress_Level: 5 unique values
# Self_Study_Hrs: 7 unique values
# Tutoring_Hrs_Wk: 5 unique values
# AI_Tool_Usage: 5 unique values
# Social_Media_Hrs: 4 unique values
# Gaming_Hrs: 5 unique values
# Exercise_Days_Wk: 4 unique values
# Sleep_Hrs: 6 unique values
# Attendance_Rate: 4 unique values
# Commute_Time: 4 unique values
# Study_Group_Freq: 4 unique values
# Extracurricular: 2 unique values
# Performance_Tier: 4 unique values

# %%
numeric_cols= df.select_dtypes(include=['int64', 'float64']).columns
for col in numeric_cols:
    print(f"{col}: {df[col].nunique()} unique values")
# Out:
# Age: 10 unique values
# GPA: 223 unique values
